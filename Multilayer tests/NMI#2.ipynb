# %%
_mlfr_2layer = ['2layer_mlfr_all_community.txt', 'mLFR/2layer_mlfr_Layer1_Community.txt', 'mLFR/2layer_mlfr_Layer2_Community.txt']
_mlfr_3layer = ['3layer_mlfr_all_community.txt', 'mLFR/3layer_mlfr_Layer1_Community.txt', 'mLFR/3layer_mlfr_Layer2_Community.txt', 'mLFR/3layer_mlfr_Layer3_Community.txt']
_mlfr_4layer = ['4layer_mlfr_all_community.txt', 'mLFR/4layer_mlfr_Community.txt']
_mlfr_4layer_overlap = ['4layer_mlfr_overlap_all_community.txt', 'mLFR/4layer_mlfr_overlap_Layer1_Community.txt', 'mLFR/4layer_mlfr_overlap_Layer2_Community.txt', 'mLFR/4layer_mlfr_overlap_Layer3_Community.txt', 'mLFR/4layer_mlfr_overlap_Layer4_Community.txt']
_mlfr_2layer_mu0_0_v0 = ['2layer_mu0_allLayer.txt', 'mLFR2/2layer_mu0_Community.txt']

_mlfr_2layer_mu0_0 = ['2layermu0_all_community_merged_run1.txt', 'mLFR2/2layer_mu0_Community.txt']
_mlfr_2layer_mu0_1 = ['2layermu0.1_all_community_merged_run1.txt', 'mLFR2/2layer_mu0.1_Community.txt']
_mlfr_2layer_mu0_2 = ['2layermu0.2_all_community_merged_run1.txt', 'mLFR2/2layer_mu0.2_Community.txt']
_mlfr_2layer_mu0_3 = ['2layermu0.3_all_community_merged_run1.txt', 'mLFR2/2layer_mu0.3_Community.txt']
_mlfr_2layer_mu0_4 = ['2layermu0.4_all_community_merged_run1.txt', 'mLFR2/2layer_mu0.4_Community.txt']
_mlfr_2layer_mu0_5 = ['2layermu0.5_all_community_merged_run1.txt', 'mLFR2/2layer_mu0.5_Community.txt']

_mlfr_2layer_mu0_0_v2 = ['2layermu0_all_community.txt', 'mLFR2/2layer_mu0_Community.txt']
_mlfr_2layer_mu0_1_v2 = ['2layermu0.1_all_community.txt', 'mLFR2/2layer_mu0.1_Community.txt']
_mlfr_2layer_mu0_2_v2 = ['2layermu0.2_all_community.txt', 'mLFR2/2layer_mu0.2_Community.txt']
_mlfr_2layer_mu0_3_v2 = ['2layermu0.3_all_community.txt', 'mLFR2/2layer_mu0.3_Community.txt']
_mlfr_2layer_mu0_4_v2 = ['2layermu0.4_all_community.txt', 'mLFR2/2layer_mu0.4_Community.txt']
_mlfr_2layer_mu0_5_v2 = ['2layermu0.5_all_community.txt', 'mLFR2/2layer_mu0.5_Community.txt']

test = ['mLFR4/3layer_mu0.1_multi_Layer1_Community.txt', 'test.txt']
test2 = ['mLFR4/3layer_mu0.1_multi_Layer2_Community.txt', 'test.txt']
test3 = ['mLFR4/3layer_mu0.1_multi_Layer3_Community.txt', 'test.txt']
# test2 = ['mLFR3/2layer_mu0.1_2_Community.txt', 'testComm3.txt']
# test3 = ['mLFR3/2lazer_mu0.1_multi_Layer1_Community.txt', 'test5.txt']
test4 = ['mLFR3/2lazer_mu0.1_multi_Layer2_Community.txt', 'test5.txt']

test6_1 = [ 'mLFR3/3layer_mu0.1_multi_Layer1_Community.txt', 'test6.txt' ]
test6_2 = [ 'mLFR3/3layer_mu0.1_multi_Layer2_Community.txt', 'test6.txt' ]
test6_3 = [ 'mLFR3/3layer_mu0.1_multi_Layer3_Community.txt', 'test6.txt' ]
test7_1 = [ 'mLFR3/3layer_mu0.1_multi_Layer1_Community.txt', 'test6_single.txt' ]
test7_2 = [ 'mLFR3/3layer_mu0.1_multi_Layer2_Community.txt', 'test6_single.txt' ]
test7_3 = [ 'mLFR3/3layer_mu0.1_multi_Layer3_Community.txt', 'test6_single.txt' ]
t = [test6_1, test6_2, test6_3, test7_1, test7_2, test7_3]

inputs = [_mlfr_2layer_mu0_0, _mlfr_2layer_mu0_1, _mlfr_2layer_mu0_2, _mlfr_2layer_mu0_3, _mlfr_2layer_mu0_4, _mlfr_2layer_mu0_5, _mlfr_2layer_mu0_0_v2, _mlfr_2layer_mu0_1_v2, _mlfr_2layer_mu0_2_v2, _mlfr_2layer_mu0_3_v2, _mlfr_2layer_mu0_4_v2, _mlfr_2layer_mu0_5_v2]

# %%
out1 = ['mLFR4/2layer_mu0.1_multi_Layer1_Community.txt', '2layermu0.1_all_community_run3.txt']
out2 = ['mLFR4/2layer_mu0.1_multi_Layer2_Community.txt', '2layermu0.1_all_community_run3.txt']
out3 = ['mLFR4/2layer_mu0.2_multi_Layer1_Community.txt', '2layermu0.2_all_community_run3.txt']
out4 = ['mLFR4/2layer_mu0.2_multi_Layer2_Community.txt', '2layermu0.2_all_community_run3.txt']
out5 = ['mLFR4/2layer_mu0.3_multi_Layer1_Community.txt', '2layermu0.3_all_community_run3.txt']
out6 = ['mLFR4/2layer_mu0.3_multi_Layer2_Community.txt', '2layermu0.3_all_community_run3.txt']
out7 = ['mLFR4/3layer_mu0.1_multi_Layer1_Community.txt', '3layermu0.1_all_community_run3.txt']
out8 = ['mLFR4/3layer_mu0.1_multi_Layer2_Community.txt', '3layermu0.1_all_community_run3.txt']
out9 = ['mLFR4/3layer_mu0.1_multi_Layer3_Community.txt', '3layermu0.1_all_community_run3.txt']
out10 = ['mLFR4/3layer_mu0.2_multi_Layer1_Community.txt', '3layermu0.2_all_community_run3.txt']
out11 = ['mLFR4/3layer_mu0.2_multi_Layer2_Community.txt', '3layermu0.2_all_community_run3.txt']
out12 = ['mLFR4/3layer_mu0.2_multi_Layer3_Community.txt', '3layermu0.2_all_community_run3.txt']
out13 = ['mLFR4/3layer_mu0.3_multi_Layer1_Community.txt', '3layermu0.3_all_community_run3.txt']
out14 = ['mLFR4/3layer_mu0.3_multi_Layer2_Community.txt', '3layermu0.3_all_community_run3.txt']
out15 = ['mLFR4/3layer_mu0.3_multi_Layer3_Community.txt', '3layermu0.3_all_community_run3.txt']
out16 = ['mLFR4/4layer_mu0.1_multi_Layer1_Community.txt', '4layermu0.1_all_community_run3.txt']
out17 = ['mLFR4/4layer_mu0.1_multi_Layer2_Community.txt', '4layermu0.1_all_community_run3.txt']
out18 = ['mLFR4/4layer_mu0.1_multi_Layer3_Community.txt', '4layermu0.1_all_community_run3.txt']
out19 = ['mLFR4/4layer_mu0.1_multi_Layer4_Community.txt', '4layermu0.1_all_community_run3.txt']
out20 = ['mLFR4/4layer_mu0.2_multi_Layer1_Community.txt', '4layermu0.2_all_community_run3.txt']
out21 = ['mLFR4/4layer_mu0.2_multi_Layer2_Community.txt', '4layermu0.2_all_community_run3.txt']
out22 = ['mLFR4/4layer_mu0.2_multi_Layer3_Community.txt', '4layermu0.2_all_community_run3.txt']
out23 = ['mLFR4/4layer_mu0.2_multi_Layer4_Community.txt', '4layermu0.2_all_community_run3.txt']
out24 = ['mLFR4/4layer_mu0.3_multi_Layer1_Community.txt', '4layermu0.3_all_community_run3.txt']
out25 = ['mLFR4/4layer_mu0.3_multi_Layer2_Community.txt', '4layermu0.3_all_community_run3.txt']
out26 = ['mLFR4/4layer_mu0.3_multi_Layer3_Community.txt', '4layermu0.3_all_community_run3.txt']
out27 = ['mLFR4/4layer_mu0.3_multi_Layer4_Community.txt', '4layermu0.3_all_community_run3.txt']

out28 = ['mLFR4/2layer_mu0.1_multi_Layer1_Community.txt', '2layermu0.1_all_community_semi_agg_run1.txt']
out29 = ['mLFR4/2layer_mu0.1_multi_Layer2_Community.txt', '2layermu0.1_all_community_semi_agg_run1.txt']
out30 = ['mLFR4/2layer_mu0.2_multi_Layer1_Community.txt', '2layermu0.2_all_community_semi_agg_run1.txt']
out31 = ['mLFR4/2layer_mu0.2_multi_Layer2_Community.txt', '2layermu0.2_all_community_semi_agg_run1.txt']
out32 = ['mLFR4/2layer_mu0.3_multi_Layer1_Community.txt', '2layermu0.3_all_community_semi_agg_run1.txt']
out33 = ['mLFR4/2layer_mu0.3_multi_Layer2_Community.txt', '2layermu0.3_all_community_semi_agg_run1.txt']
out34 = ['mLFR4/3layer_mu0.1_multi_Layer1_Community.txt', '3layermu0.1_all_community_semi_agg_run1.txt']
out35 = ['mLFR4/3layer_mu0.1_multi_Layer2_Community.txt', '3layermu0.1_all_community_semi_agg_run1.txt']
out36 = ['mLFR4/3layer_mu0.1_multi_Layer3_Community.txt', '3layermu0.1_all_community_semi_agg_run1.txt']
out37 = ['mLFR4/3layer_mu0.2_multi_Layer1_Community.txt', '3layermu0.2_all_community_semi_agg_run1.txt']
out38 = ['mLFR4/3layer_mu0.2_multi_Layer2_Community.txt', '3layermu0.2_all_community_semi_agg_run1.txt']
out39 = ['mLFR4/3layer_mu0.2_multi_Layer3_Community.txt', '3layermu0.2_all_community_semi_agg_run1.txt']
out40 = ['mLFR4/3layer_mu0.3_multi_Layer1_Community.txt', '3layermu0.3_all_community_semi_agg_run1.txt']
out41 = ['mLFR4/3layer_mu0.3_multi_Layer2_Community.txt', '3layermu0.3_all_community_semi_agg_run1.txt']
out42 = ['mLFR4/3layer_mu0.3_multi_Layer3_Community.txt', '3layermu0.3_all_community_semi_agg_run1.txt']
out43 = ['mLFR4/4layer_mu0.1_multi_Layer1_Community.txt', '4layermu0.1_all_community_semi_agg_run1.txt']
out44 = ['mLFR4/4layer_mu0.1_multi_Layer2_Community.txt', '4layermu0.1_all_community_semi_agg_run1.txt']
out45 = ['mLFR4/4layer_mu0.1_multi_Layer3_Community.txt', '4layermu0.1_all_community_semi_agg_run1.txt']
out46 = ['mLFR4/4layer_mu0.1_multi_Layer4_Community.txt', '4layermu0.1_all_community_semi_agg_run1.txt']
out47 = ['mLFR4/4layer_mu0.2_multi_Layer1_Community.txt', '4layermu0.2_all_community_semi_agg_run1.txt']
out48 = ['mLFR4/4layer_mu0.2_multi_Layer2_Community.txt', '4layermu0.2_all_community_semi_agg_run1.txt']
out49 = ['mLFR4/4layer_mu0.2_multi_Layer3_Community.txt', '4layermu0.2_all_community_semi_agg_run1.txt']
out50 = ['mLFR4/4layer_mu0.2_multi_Layer4_Community.txt', '4layermu0.2_all_community_semi_agg_run1.txt']
out51 = ['mLFR4/4layer_mu0.3_multi_Layer1_Community.txt', '4layermu0.3_all_community_semi_agg_run1.txt']
out52 = ['mLFR4/4layer_mu0.3_multi_Layer2_Community.txt', '4layermu0.3_all_community_semi_agg_run1.txt']
out53 = ['mLFR4/4layer_mu0.3_multi_Layer3_Community.txt', '4layermu0.3_all_community_semi_agg_run1.txt']
out54 = ['mLFR4/4layer_mu0.3_multi_Layer4_Community.txt', '4layermu0.3_all_community_semi_agg_run1.txt']

outs = [out1, out2, out3, out4, out5, out6, out7, out8, out9, out10, out11, out12, out13, out14, out15, out16, out17, out18, out19, out20, out21, out22, out23, out24, out25, out26, out27, out28, out29, out30, out31, out32, out33, out34, out35, out36, out37, out38, out39, out40, out41, out42, out43, out44, out45, out46, out47, out48, out49, out50, out51, out52, out53, out54]

# %%
test1 = ['pTest_alpha0.1.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test2 = ['pTest_alpha0.1.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test3 = ['pTest_alpha0.1.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test4 = ['pTest_alpha0.30000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test5 = ['pTest_alpha0.30000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test6 = ['pTest_alpha0.30000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test7 = ['pTest_alpha0.5000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test8 = ['pTest_alpha0.5000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test9 = ['pTest_alpha0.5000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test10 = ['pTest_alpha0.7000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test11 = ['pTest_alpha0.7000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test12 = ['pTest_alpha0.7000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test13 = ['pTest_alpha0.9000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test14 = ['pTest_alpha0.9000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test15 = ['pTest_alpha0.9000000000000001.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test16 = ['pTest_alpha1.1000000000000003.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test17 = ['pTest_alpha1.1000000000000003.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test18 = ['pTest_alpha1.1000000000000003.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test19 = ['pTest_alpha1.3000000000000003.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test20 = ['pTest_alpha1.3000000000000003.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test21 = ['pTest_alpha1.3000000000000003.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test22 = ['pTest_alpha1.5000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test23 = ['pTest_alpha1.5000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test24 = ['pTest_alpha1.5000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test25 = ['pTest_alpha1.7000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test26 = ['pTest_alpha1.7000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test27 = ['pTest_alpha1.7000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']
test28 = ['pTest_alpha1.9000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer1_Community.txt']
test29 = ['pTest_alpha1.9000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer2_Community.txt']
test30 = ['pTest_alpha1.9000000000000004.txt', 'mLFR4/3layer_mu0.1_multi_Layer3_Community.txt']

test = [test1, test2, test3, test4, test5, test6, test7, test8, test9, test10, test11, test12, test13, test14, test15, test16, test17, test18, test19, test20, test21, test22, test23, test24, test25, test26, test27, test28, test29, test30]

# %%
import networkx as nx
import numpy as np
import pandas as pd

from community import best_partition

from sklearn.metrics.cluster import normalized_mutual_info_score as NMI
from sklearn.metrics.cluster import adjusted_mutual_info_score as AMI

# %%
inputs = test
base = None
scores = pd.DataFrame(columns=['Layer', 'NMIScore', 'AMIScore'])
for mlfrInput in inputs:
  for i in range(len(mlfrInput)):
    fileName = mlfrInput[i]
    if i == 0:
      base = pd.read_csv(fileName, sep=" ", header=None)
      base = np.array(base[1].values)
    else:
      currentLayer = pd.read_csv(fileName, sep=" ", header=None)
      currentLayer = np.array(currentLayer[1].values)
      scores = scores.append({'Layer' : mlfrInput[0] + '--' + fileName, 'NMIScore' : NMI(base, currentLayer), 'AMIScore' : AMI(base, currentLayer)}, ignore_index=True)
scores
# Out:
#                                                 Layer  NMIScore  AMIScore
# 0   pTest_alpha0.1.txt--mLFR4/3layer_mu0.1_multi_L...  0.965066  0.924632
# 1   pTest_alpha0.1.txt--mLFR4/3layer_mu0.1_multi_L...  0.951892  0.899203
# 2   pTest_alpha0.1.txt--mLFR4/3layer_mu0.1_multi_L...  0.909258  0.816911
# 3   pTest_alpha0.30000000000000004.txt--mLFR4/3lay...  0.946154  0.862178
# 4   pTest_alpha0.30000000000000004.txt--mLFR4/3lay...  0.930248  0.831287
# 5   pTest_alpha0.30000000000000004.txt--mLFR4/3lay...  0.879661  0.733046
# 6   pTest_alpha0.5000000000000001.txt--mLFR4/3laye...  0.944898  0.842589
# 7   pTest_alpha0.5000000000000001.txt--mLFR4/3laye...  0.931999  0.817412
# 8   pTest_alpha0.5000000000000001.txt--mLFR4/3laye...  0.885576  0.726802
# 9   pTest_alpha0.7000000000000001.txt--mLFR4/3laye...  0.912819  0.754374
# 10  pTest_alpha0.7000000000000001.txt--mLFR4/3laye...  0.901927  0.732999
# 11  pTest_alpha0.7000000000000001.txt--mLFR4/3laye...  0.868458  0.667321
# ...
