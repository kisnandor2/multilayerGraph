# %%
import networkx as nx
import numpy as np
import pandas as pd
import community as comm

# %%
# b = '2layermu0.1_base.txt'
b = '2layermu0.2_all_community_merged_run1.txt'
# b = 'mLFR2/2layer_mu0.1_Community.txt'
base = pd.read_csv(b, sep=" ", header=None)
base = np.array(base[1].values)

graphs = ['mLFR2/2layer_mu0.2_Layer1_Network.txt.txt', 'mLFR2/2layer_mu0.2_Layer2_Network.txt.txt']
A = pd.read_csv(graphs[0], sep=" ", header=None)
G1 = nx.from_numpy_matrix(np.array(A))

A = pd.read_csv(graphs[1], sep=" ", header=None)
G2 = nx.from_numpy_matrix(np.array(A))

H1 = mergeLayers([G1, G2], 0, alpha = np.full(2, 0.5))

# %%
_max = 0
t = 0
partition = {}
x = base
for val, ind in zip(np.nditer(x), np.ndindex(x.shape[0])):
  partition[ind[0]] = int(val)

for i in np.arange(0.1,2.1,0.1):
  alpha = np.full(2, i)
  H1 = mergeLayers([G1, G2], 0, alpha)
  alpha = np.full(2, i)
  H2 = mergeLayers([G1, G2], 1, alpha)
  
  print(i)
  m = comm.modularity(partition, H1, weight='weight')
  
  print(m)
  m += comm.modularity(partition, H2, weight='weight')
  print(comm.modularity(partition, H2, weight='weight'))
  if m > _max:
    _max = m
    t = i
  print()
print(t)
print(_max)
# Out:
# 0.1
# 0.28848379629629606
# 0.4227050910726396
#
# 0.2
# 0.30084181914073604
# 0.41020696405179996
#
# 0.30000000000000004
# 0.3113096885813149
# 0.39964287820074273
#
# 0.4
# 0.32029024455791494
# 0.3905961449676829
#
# 0.5
# 0.3280794460641399
# 0.38276175587548483
#
# 0.6
# 0.3348996131040951
# 0.37591131673605377
#
# 0.7000000000000001
# 0.3409209885561232
# 0.3698704133333086
#
# 0.8
# 0.3462761430511548
# 0.36450355371493126
#
# 0.9
# 0.3510698491155054
# 0.3597038845544208
#
# 1.0
# 0.3553860043158497
# 0.3553860043158497
#
# 1.1
# 0.3592925835153707
# 0.35148083722243884
#
# 1.2000000000000002
# 0.36284524517719013
# 0.3479319100565634
#
# 1.3000000000000003
# 0.3660900000000003
# 0.34469260343386243
#
# 1.4000000000000001
# 0.3690652145066296
# 0.34172409243128343
#
# 1.5000000000000002
# 0.37180313523279007
# 0.3389937829642432
#
# 1.6
# 0.3743310622079517
# 0.3364741100525666
#
# 1.7000000000000002
# 0.3766722623966937
# 0.33414160388863734
#
# 1.8000000000000003
# 0.37884668793394694
# 0.3319761565758645
#
# 1.9000000000000001
# 0.38087154614932356
# 0.32996044097312976
#
# 2.0
# 0.38276175587548483
# 0.3280794460641399
#
# 0.1
# 0.7111888873689356

# %%
def mergeLayers(G, mainLayer, alpha):
  alpha[mainLayer] = 1 #take the mainLayer's weights without scaling
  H = nx.Graph()
  for i in range(len(G)):
    g = G[i]
    for e in g.edges().data('weight'):
      (u, v, weight) = e
      if (u,v) not in H.edges():
        H.add_edge(u,v, weight=weight*alpha[i])
      else:
        H[u][v]['weight'] = H[u][v]['weight'] + weight*alpha[i]
#   print(H.edges.data())
  return H

# %%
_max = 0
(oo, tt) = (None, None)
for (o, t) in [(o,t) for o in np.arange(0,1.1,0.1) for t in np.arange(0,1.1,0.1)]:
  A = np.zeros((7,7))

  A[0,1] = A[1,0] = o
  A[0,2] = A[2,0] = o
  A[0,3] = A[3,0] = o
  A[1,2] = A[2,1] = o
  A[2,3] = A[3,2] = o
  A[2,4] = A[4,2] = o

  # A[1,3] = A[3,1] = 1

  A[4,5] = A[5,4] = t
  A[4,6] = A[6,4] = t
  A[5,6] = A[6,5] = t

  k = np.sum(A,1)
  m = sum(k)/2

  s = [1,1,1,1,0,0,0]

  q = 0
  for i in range(0,7):
    for j in range(0,7):
      q += (A[i,j] - (k[i]*k[j])/(2*m)) * (s[i]*s[j])
      
  qq = q/m    
  print(q/m)
  # Layer 2
  A = np.zeros((7,7))

  A[0,3] = A[3,0] = t
  A[1,2] = A[2,1] = t
  
  # A[1,3] = A[3,1] = 1

  A[4,5] = A[5,4] = o
  A[4,6] = A[6,4] = o
  A[5,6] = A[6,5] = o

  k = np.sum(A,1)
  m = sum(k)/2

  s = [1,1,1,1,0,0,0]

  q = 0
  for i in range(0,7):
    for j in range(0,7):
      q += (A[i,j] - (k[i]*k[j])/(2*m)) * (s[i]*s[j])
  print(q/m)
  qq += q/m
  print("qq: " + str(qq))
  print("")
  if qq > _max:
    (oo, tt) = (o, t)
    _max = qq
print("")
print(oo, tt, _max)
# Out:
# nan
# nan
# qq: nan
#
# 0.0
# -3.122502256758253e-16
# qq: -3.122502256758253e-16
#
# 0.0
# -3.122502256758253e-16
# qq: -3.122502256758253e-16
#
# 0.0
# 0.0
# qq: 0.0
#
# 0.0
# -3.122502256758253e-16
# qq: -3.122502256758253e-16
#
# 0.0
# 0.0
# qq: 0.0
#
# 0.0
# 0.0
# qq: 0.0
#
# 0.0
# -1.189524669241239e-16
# qq: -1.189524669241239e-16
#
# 0.0
# -3.122502256758253e-16
# qq: -3.122502256758253e-16
#
# 0.0
# 3.0839528461809905e-17
# qq: 3.0839528461809905e-17
#
# 0.0
# 0.0
# qq: 0.0
#
# -0.013888888888888838
# 0.0
# qq: -0.013888888888888838
#
# 0.3641975308641975
# 0.47999999999999976
# qq: 0.8441975308641972
#
# 0.4131944444444444
# 0.48979591836734687
# qq: 0.9029903628117912
#
# 0.3977777777777778
# 0.4444444444444446
# qq: 0.8422222222222224
#
# 0.36882716049382724
# 0.39669421487603285
# qq: 0.7655213753698601
#
# 0.3390022675736962
# 0.35502958579881666
# qq: 0.6940318533725129
#
# 0.3116319444444445
# 0.3200000000000002
# qq: 0.6316319444444447
#
# 0.2873799725651577
# 0.29065743944636696
# qq: 0.5780374120115246
#
# 0.2661111111111111
# 0.2659279778393354
# qq: 0.5320390889504465
#
# 0.2474747474747475
# 0.24489795918367355
# qq: 0.49237270665842103
#
# 0.2310956790123457
# 0.22684310018903608
# qq: 0.4579387792013818
#
# -0.013888888888888838
# 0.0
# qq: -0.013888888888888838
#
# 0.2577777777777777
# 0.37500000000000006
# qq: 0.6327777777777778
#
# 0.3641975308641975
# 0.47999999999999976
# qq: 0.8441975308641972
#
# 0.40362811791383224
# 0.5
# qq: 0.9036281179138322
#
# 0.4131944444444444
# 0.48979591836734687
# qq: 0.9029903628117912
#
# 0.4087791495198902
# 0.46875000000000006
# qq: 0.8775291495198903
#
# 0.3977777777777778
# 0.4444444444444446
# qq: 0.8422222222222224
#
# 0.3838383838383838
# 0.4199999999999998
# qq: 0.8038383838383836
#
# 0.36882716049382724
# 0.39669421487603285
# qq: 0.7655213753698601
#
# 0.3537146614069691
# 0.37500000000000017
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:51: RuntimeWarning: invalid value encountered in double_scalars

# %%
g = nx.from_numpy_matrix(A)
partition = {}
x = np.array(s)
for val, ind in zip(np.nditer(x), np.ndindex(x.shape[0])):
  partition[ind[0]] = int(val)
  
comm.modularity(partition, g)
# Out:
# -0.013888888888888753

# %%
A = np.zeros((7,7))

o = 1
t = 0.5
A[0,1] = A[1,0] = o
A[0,2] = A[2,0] = o
A[0,3] = A[3,0] = o
A[1,2] = A[2,1] = o
A[2,3] = A[3,2] = o
A[2,4] = A[4,2] = o

# A[1,3] = A[3,1] = 1

A[4,5] = A[5,4] = t
A[4,6] = A[6,4] = t
A[5,6] = A[6,5] = t

k = np.sum(A,1)
m = sum(k)/2

s = [1,1,1,1,0,0,0]

g = nx.from_numpy_matrix(A)

pizzutiFitness(g, np.array(s))
# Out:
# 2.7483482335058627

# %%
def pizzutiFitness(g, x, alpha=0.5):
  
  _max = 0
  for node in g.nodes():
    for i in g[node]:
      if g[node][i]['weight'] > _max:
        _max = g[node][i]['weight']
  _max
  
  d = {}
  for val, ind in zip(np.nditer(x), np.ndindex(x.shape[0])):
    d[ind[0]] = int(val)

  partitions = []
  for partitionNumber in set(d.values()):
    partition = []
    for key in d:
      if d[key] == partitionNumber:
        partition.append(key)
    partitions.append(partition)  

  fitness = 0

  for partition in partitions:
    k_out = 0
    for node in partition:
      for i, datas in g[node].items():
        if i not in partition:
          k_out += datas.get('weight', 1)/_max

    k_in = 0
    for node in partition:
      for i, datas in g[node].items():
        if i in partition:
          k_in += datas.get('weight', 1)/_max
    k_in = k_in//2

    fitness += k_in/((k_in + k_out)**(alpha))
  
  return fitness

# %%
_max = 0
t = 0
partition = {}

for i in np.arange(0,0.2,0.01):
  alpha = np.full(2, i)
  H1 = mergeLayers([G1, G2], 0, alpha)
  alpha = np.full(2, i)
  H2 = mergeLayers([G1, G2], 1, alpha)
  
  print(i)
  m = pizzutiFitness(H1, np.array(base))
  
  print(m)
  m += pizzutiFitness(H2, np.array(base))
  print(pizzutiFitness(H2, np.array(base)))
  if m > _max:
    _max = m
    t = i
  print()
print(t)
print(_max)
# Out:
# 0.0
# 22.82994100716539
# 20.385071939409453
#
# 0.01
# 19.50310599569272
# 19.273594162203675
#
# 0.02
# 19.424199640052855
# 19.261587498916725
#
# 0.03
# 19.503125120364086
# 19.249915855511517
#
# 0.04
# 19.42433041076928
# 19.238565522647267
#
# 0.05
# 19.503364157138325
# 19.22752352953186
#
# 0.06
# 19.503558285038505
# 19.13782766860446
#
# 0.07
# 19.503798329514506
# 19.127366604118496
#
# 0.08
# 19.504081631684905
# 19.196127950396686
#
# 0.09
# 19.504405686292646
# 19.10725414107281
#
# 0.1
# 19.504768131718233
# 19.176530483680025
#
# 0.11
# 19.426273322698513
# 19.16710175244483
#
# 0.12
# 19.326719235374316
# 18.897822623843524
#
# 0.13
# 19.427169434674173
# 19.148939338940465
#
# 0.14
# 19.506559117194772
# 19.14018896780914
#
# 0.15
# 19.507082508821632
# 19.052702623313127
#
# 0.16
# 19.50763266450502
# 19.12331110415066
#
# 0.17
# 19.5082080034476
# 19.115169171260632
#
# 0.18
# 19.508807030672553
# 19.107216160942738
#
# 0.19
# 19.509428331881654
# 19.099445650263444
#
# 0.0
# 43.215012946574845

# %%
# Out:
# 1.5
